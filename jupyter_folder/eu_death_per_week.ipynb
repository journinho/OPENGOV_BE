# %%
import pandas as pd

# %%
df = pd.read_table('https://ec.europa.eu/eurostat/estat-navtree-portlet-prod/BulkDownloadListing?file=data/demo_nsinrt.tsv.gz', sep='\t')
df.head(10)
# Out:
#   unit,sex,age,agedef,geo\time     2020      2019      2018      2017   \
# 0        NR,F,TOTAL,COMPLET,AM        :   0.68848   0.63322   0.61924
# 1        NR,F,TOTAL,COMPLET,AT        :   0.61855   0.62871   0.60881
# 2        NR,F,TOTAL,COMPLET,AZ        :   0.84265   0.80086   0.78228
# 3        NR,F,TOTAL,COMPLET,BE  0.31008         :         :   0.42931
# 4        NR,F,TOTAL,COMPLET,BG  0.50948   0.65993   0.64199   0.61562
# 5        NR,F,TOTAL,COMPLET,BY        :         :   0.73379   0.79146
# 6        NR,F,TOTAL,COMPLET,CH  0.51141   0.56619   0.59509   0.59278
# 7        NR,F,TOTAL,COMPLET,CY        :         :         :         :
# 8        NR,F,TOTAL,COMPLET,CZ  0.53677   0.64840   0.63455   0.60469
# 9        NR,F,TOTAL,COMPLET,DE        :         :         :   0.61929
#
#       2016      2015      2014      2013      2012   ...     1999      1998   \
# 0        :   0.66165         :         :         :   ...        :         :
# ...

# %%
print(df.dtypes)
# Out:
# unit,sex,age,agedef,geo\time    object
# 2020                            object
# 2019                            object
# 2018                            object
# 2017                            object
# 2016                            object
# 2015                            object
# 2014                            object
# 2013                            object
# 2012                            object
# 2011                            object
# 2010                            object
# 2009                            object
# 2008                            object
# 2007                            object
# 2006                            object
# 2005                            object
# 2004                            object
# 2003                            object
# 2002                            object
# 2001                            object
# 2000                            object
# 1999                            object
# 1998                            object
# ...
