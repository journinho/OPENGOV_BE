# %%
# !pip install eurostat

# %%
import eurostat 
import pandas as pd

# %%
print(eurostat.get_dic(code, 'sex', lang='de'))
# Out:
# [('T', 'Insgesamt'), ('M', 'Männer'), ('F', 'Frauen'), ('DIFF', 'Absolute Differenz zwischen Männern und Frauen'), ('NAP', 'Nicht anwendbar'), ('NRP', 'Keine Antwort'), ('UNK', 'Unbekannt')]

# %%
code = 'ilc_pns6'
data = eurostat.get_data_df(code)

# %%
data
# Out:
#     freq wstatus     age   indic_il sex geo\TIME_PERIOD  1995  1996  1997  \
# 0      A     RET  Y_GE18  LI_R_MD60   F              AL   NaN   NaN   NaN
# 1      A     RET  Y_GE18  LI_R_MD60   F              AT   NaN   NaN   NaN
# 2      A     RET  Y_GE18  LI_R_MD60   F              BE   NaN   NaN   NaN
# 3      A     RET  Y_GE18  LI_R_MD60   F              BG   NaN   NaN   NaN
# 4      A     RET  Y_GE18  LI_R_MD60   F              CH   NaN   NaN   NaN
# ..   ...     ...     ...        ...  ..             ...   ...   ...   ...
# 262    A     RET  Y_GE65  LI_R_MD60   T              SI   NaN   NaN   NaN
# 263    A     RET  Y_GE65  LI_R_MD60   T              SK   NaN   NaN   NaN
# 264    A     RET  Y_GE65  LI_R_MD60   T              TR   NaN   NaN   NaN
# 265    A     RET  Y_GE65  LI_R_MD60   T              UK  33.0  29.0  26.0
# 266    A     RET  Y_GE65  LI_R_MD60   T              XK   NaN   NaN   NaN
#
#      1998  ...  2012  2013  2014  2015  2016  2017  2018  2019  2020  2021
# ...

# %%
# Out:
# ['BE', 'DE', 'ES', 'AT']

# %%
data = es.get_data_df(code)

# %%
eu_toc = es.get_toc_df()

# %%
eu_toc
# Out:
#                                                   title  \
# 0     Arrivals of residents/non-residents at tourist...
# 1     Nights spent at tourist accommodation establis...
# 2     Nights spent at tourist accommodation establis...
# 3     Nights spent at tourist accommodation establis...
# 4     Nights spent at tourist accommodation establis...
# ...                                                 ...
# 7358                                    Postal services
# 7359  Access points  (USP under direct or indirect d...
# 7360    Number of enterprises providing postal services
# 7361  Employment related to the provision of  postal...
# 7362  Turnover from the provision of postal services...
#
#                          code     type       last update of data  \
# 0                    TIN00174  dataset  2022-09-08T23:00:00+0200
# 1                    TIN00175  dataset  2022-09-08T23:00:00+0200
# 2                    TIN00176  dataset  2022-02-09T23:00:00+0100
# ...

# %%
es.get_dic(code, full=True, frmt="list", lang="nl")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/23/8w2q1vrx7yl15vpmhhd3l44r0000gp/T/ipykernel_79284/4292754149.py in <cell line: 1>()
# ----> 1 es.get_dic(code, full=True, frmt="list", lang="nl")
#
# TypeError: get_dic() missing 1 required positional argument: 'par'

# %%
toc_df = eurostat.get_toc_df()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/23/8w2q1vrx7yl15vpmhhd3l44r0000gp/T/ipykernel_79284/962871873.py in <cell line: 1>()
# ----> 1 toc_df = eurostat.get_toc_df(lang='nl')
#
# TypeError: get_toc_df() got an unexpected keyword argument 'lang'

# %%
toc_df
# Out:
#                                                   title  \
# 0     Arrivals of residents/non-residents at tourist...
# 1     Nights spent at tourist accommodation establis...
# 2     Nights spent at tourist accommodation establis...
# 3     Nights spent at tourist accommodation establis...
# 4     Nights spent at tourist accommodation establis...
# ...                                                 ...
# 7358                                    Postal services
# 7359  Access points  (USP under direct or indirect d...
# 7360    Number of enterprises providing postal services
# 7361  Employment related to the provision of  postal...
# 7362  Turnover from the provision of postal services...
#
#                          code     type       last update of data  \
# 0                    TIN00174  dataset  2022-09-08T23:00:00+0200
# 1                    TIN00175  dataset  2022-09-08T23:00:00+0200
# 2                    TIN00176  dataset  2022-02-09T23:00:00+0100
# ...

# %%
# make toc_df['code'] as list
code_list = toc_df['code'].str.split(', ')

# %%
print(code_list)
# Out:
# 0                      [TIN00174]
# 1                      [TIN00175]
# 2                      [TIN00176]
# 3                      [TIN00177]
# 4                      [TIN00178]
#                   ...
# 7358               [POST_CUBE1_X]
# 7359    [POST_CUBE1_X$POST_ACC_1]
# 7360        [POST_CUBE1_X$NUM701]
# 7361    [POST_CUBE1_X$POST_EMP_1]
# 7362    [POST_CUBE1_X$POST_FIN_1]
# Name: code, Length: 7363, dtype: object

# %%
#iterate thru code_list
for code in code_list:
    df = eurostat.get_data_df(code[0])
    df.to_csv(f'{code}.csv')
